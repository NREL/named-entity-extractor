# %%
#! pip install -U spacy -q

# %%
#!python -m spacy download en_core_web_lg

# %%
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.7.2
# Location         C:\Python310\lib\site-packages\spacy
# Platform         Windows-10-10.0.19045-SP0
# Python version   3.10.10
# Pipelines        en_core_web_lg (3.7.0), en_core_web_sm (3.7.0), en_core_web_trf (3.7.2)

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

# %%
import json

# %%
! python -m spacy debug data config_acc_cpu.cfg --paths.train ./Components/03HVAC/training_data_new.spacy --paths.dev ./Components/03HVAC/validation_data_new.spacy
# Out:
# ============================ Data file validation ============================
# [+] Pipeline can be initialized with data
# [+] Corpus is loadable
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: tok2vec, ner
# 936 training docs
# 524 evaluation docs
# [!] 324 training examples also in evaluation data
# [!] Low number of examples to train a new pipeline (936)
#
# ============================== Vocab & Vectors ==============================
# [i] 9883 total word(s) in the data (655 unique)
# [i] 514157 vectors (514157 unique keys, 300 dimensions)
# [!] 1141 words in training data without vectors (12%)
#
# ========================== Named Entity Recognition ==========================
# [i] 11 label(s)
# 0 missing value(s) (tokens with '-' label)
# [!] Low number of examples for label 'SYSTEM_TYPE' (39)
#
# [!] Low number of examples for label 'VOLTAGE' (16)
#
# ...

# %%
! python -m spacy debug data config_acc_cpu.cfg --paths.train ./Components/05Electrical/training_data_new.spacy --paths.dev ./Components/05Electrical/validation_data_new.spacy
# Out:
# ============================ Data file validation ============================
# [+] Pipeline can be initialized with data
# [+] Corpus is loadable
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: tok2vec, ner
# 472 training docs
# 238 evaluation docs
# [!] 233 training examples also in evaluation data
# [!] Low number of examples to train a new pipeline (472)
#
# ============================== Vocab & Vectors ==============================
# [i] 5115 total word(s) in the data (259 unique)
# [i] 514157 vectors (514157 unique keys, 300 dimensions)
# [!] 675 words in training data without vectors (13%)
#
# ========================== Named Entity Recognition ==========================
# [i] 9 label(s)
# 0 missing value(s) (tokens with '-' label)
# [!] Low number of examples for label 'MOUNTING_TYPE' (19)
#
# [!] Low number of examples for label 'LENGTH' (3)
#
# ...

# %%
! python -m spacy debug data config_acc_cpu.cfg --paths.train ./Components/02Plumbing/training_data_new.spacy --paths.dev ./Components/02Plumbing/validation_data_new.spacy
# Out:
# ============================ Data file validation ============================
# [+] Pipeline can be initialized with data
# [+] Corpus is loadable
#
# =============================== Training stats ===============================
# Language: en
# Training pipeline: tok2vec, ner
# 165 training docs
# 89 evaluation docs
# [!] 88 training examples also in evaluation data
# [!] Low number of examples to train a new pipeline (165)
#
# ============================== Vocab & Vectors ==============================
# [i] 1831 total word(s) in the data (238 unique)
# [i] 514157 vectors (514157 unique keys, 300 dimensions)
# [!] 277 words in training data without vectors (15%)
#
# ========================== Named Entity Recognition ==========================
# [i] 8 label(s)
# 0 missing value(s) (tokens with '-' label)
# [!] Low number of examples for label 'SIZE' (34)
#
# [!] Low number of examples for label 'LOA' (20)
#
# [+] Examples without occurrences available for all labels
# ...

# %%
nlp_ner = spacy.load("Components/03HVAC/cpu_acc_new/model-best") 
# Open and read the text file
with open("Components/hvac-unique.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

# Process each line with the NER model
for line in lines:
    line = line.strip()  # Remove leading/trailing whitespace
    doc = nlp_ner(line)
    spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# Out:
# C:\Python310\lib\site-packages\spacy\displacy\__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">2-Pipe Heating/Cooling Distribution Steel Piping -  1 IN</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">2-Pipe Heating/Cooling Distribution Steel Piping -  3 IN</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     208-240 volt
# ...

# %%
nlp_ner = spacy.load("Components/02Plumbing/cpu_acc_new/model-best") 
# Open and read the text file
with open("Components/plumbing-unique.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

# Process each line with the NER model
for line in lines:
    line = line.strip()  # Remove leading/trailing whitespace
    doc = nlp_ner(line)
    spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Backflow Preventer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EQUIPMENT</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Backflow Preventer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EQUIPMENT</span>
# </mark>
#  -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
nlp_ner = spacy.load("Components/05Electrical/cpu_acc_new/model-best") 
# Open and read the text file
with open("Components/electrical-unique.txt", "r", encoding="utf-8") as file:
    lines = file.readlines()

# Process each line with the NER model
for line in lines:
    line = line.strip()  # Remove leading/trailing whitespace
    doc = nlp_ner(line)
    spacy.displacy.render(doc, style="ent", jupyter=True) # display in Jupyter
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">6 outlets</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">6 stations</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">12 outlets</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">12 stations</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">25 stations</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">30 outlets</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">50 stations</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">100 outlets</div></span>
# ...
